# %% [markdown]
# #### test notebook for skeleton plot

# %%
import skeleton_plot as skelplot
from skeleton_plot.skel_io import *
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
# %matplotlib inline

# %%
#various google cloud paths 

#raw skeleton files
skel_path = 'https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily-pcg-skeletons/minnie_all/BIL_neurons/file_groups/'
skel_dir = '864691134884807418_518848'
skel_filename = '864691134884807418_518848.swc'

# upright
upright_path = 'https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily_skeleton_keys/upright/BIL_excitatory/'

# layer aligned
layer_aligned_path = 'https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily_skeleton_keys/layer_align/BIL_excitatory/'


# polygon files (layer bounds for each cell)
# gives 2d shape for each layer 
layer_bounds_path = 'https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily_skeleton_keys/poly_files/BIL_polys/'

# average layer bounds from IVSCC (to which layer aligned celled are alligned)
# this just gives a single value for each layer (straight line)
layer_bounds_average_path = "https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily_skeleton_keys/avg_layer_depths/"
avg_layerdepths_filename = 'mouse_me_and_met_avg_layer_depths.json'


# mesh path with gs://
mw_path = 'gs://allen-minnie-phase3/minniephase3-emily-pcg-skeletons/minnie_all/BIL_neurons/file_groups/'


rid = 864691134884807418
sid = 518848

# %%
# successful run 
depths = read_json(layer_bounds_average_path, avg_layerdepths_filename)
depths
# Out:
# {'2/3': 115.1112491335,
#  '4': 333.4658190171,
#  '5': 453.6227158132,
#  '6a': 687.6482650269,
#  '6b': 883.1308910545,
#  'wm': 922.5861720311}

# %%
# now https version 
depths = read_json('https://storage.googleapis.com/allen-minnie-phase3/minniephase3-emily_skeleton_keys/avg_layer_depths/',
                                         avg_layerdepths_filename)
depths
# Out:
# {'2/3': 115.1112491335,
#  '4': 333.4658190171,
#  '5': 453.6227158132,
#  '6a': 687.6482650269,
#  '6b': 883.1308910545,
#  'wm': 922.5861720311}

# %%
# should raise error
depths = read_json('layer_bounds_average_path', 'avg_layerdepths_filename')
depths
# Out:
# ---------------------------------------------------------------------------
# UnsupportedProtocolError                  Traceback (most recent call last)
# <ipython-input-10-47d6f6f77dbc> in <module>
#       1 # should raise error
# ----> 2 depths = read_json('layer_bounds_average_path', 'avg_layerdepths_filename')
#       3 depths
#
# ~/Work/Repos/skeleton_plot/skeleton_plot/skel_io.py in read_json(directory, filename)
#      33         raise ImportError('cannot use read_depths without cloudfiles.Install https://github.com/seung-lab/cloud-files to continue')
#      34
# ---> 35     cf = CloudFiles(directory)
#      36     js = cf.get_json(filename)
#      37
#
# /opt/anaconda3/envs/work/lib/python3.8/site-packages/cloudfiles/cloudfiles.py in __init__(self, cloudpath, progress, green, secrets, num_threads, use_https, endpoint, parallel, request_payer)
#     243     self.request_payer = request_payer
#     244
# --> 245     self._path = paths.extract(cloudpath)
#     246     if endpoint:
#     247       self._path = paths.ExtractedPath(host=endpoint, **self._path)
#
# /opt/anaconda3/envs/work/lib/python3.8/site-packages/cloudfiles/paths.py in extract(cloudpath, windows)
#     170
#     171   if protocol is None:
# --> 172     raise error
#     173
#     174   return ExtractedPath(
#
# UnsupportedProtocolError:
# Cloud Path must conform to [FORMAT://]PROTOCOL://PATH
# Examples:
#   precomputed://gs://test_bucket/em
#   gs://test_bucket/em
#   graphene://https://example.com/image/em
#
# Supported Formats: None (precomputed), graphene, precomputed, boss
# Supported Protocols: gs, file, s3, matrix, http, https, mem
#
# Cloud Path Recieved: layer_bounds_average_path

# %%
# plot the radius from the swc 
rid = 864691134884807418
sid = 518848
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')



f , ax = plt.subplots(figsize=(7,10))
skelplot.plot_tools.plot_skel(sk,  ax=ax, pull_radius = True, pull_compartment_colors = True,
                              invert_y=True, plot_soma = True, 
                             line_width = 3, color = 'darkslategray')

# %%
# invert y and x 
f , ax = plt.subplots(figsize=(7,10))
skelplot.plot_tools.plot_skel(sk, ax = ax, title=rid,  pull_radius = True, pull_compartment_colors = True,
                              invert_y=True, plot_soma = True, x = 'z', y = 'y',
                             line_width = 3)

# %%
# plot with constant radius 
f , ax = plt.subplots(figsize=(7,10))

skelplot.plot_tools.plot_skel(sk, title=rid, line_width=1, plot_soma=True, 
                                invert_y=True, pull_compartment_colors = True)

# %%
# check other swcs of mine, upright, layer aligned, etc

# %%
# plot some thicker skeletons with radius map 
rid = 864691135754974674
sid = 300897
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')
f , ax = plt.subplots(figsize=(7,10))


skelplot.plot_tools.plot_skel(sk, title=rid,  pull_radius = True,
                              invert_y=True, line_width=1, pull_compartment_colors = True)

# %%
rid = 864691135407549129
sid = 265045
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')
f , ax = plt.subplots(figsize=(7,10))


skelplot.plot_tools.plot_skel(sk, title=rid,  pull_radius = True,
                              invert_y=True, line_width = 5, color = 'maroon')

# %%
rid = 864691135212946560
sid = 301225
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')
f , ax = plt.subplots(figsize=(7,10))


skelplot.plot_tools.plot_skel(sk, title=rid,  pull_radius = True,
                              invert_y=True, line_width = 1, plot_soma = True,
                             pull_compartment_colors = True)

swc_path = f'{skel_path}{rid}_{sid}/{rid}_{sid}.swc'
read_swc(swc_path)
# Out:
#         id  type        x        y        z  radius  parent
# 0        0     1  755.840  737.664  881.360   6.817      -1
# 1        1     4  757.408  730.578  879.278   0.655       0
# 2        2     4  757.721  729.161  878.862   0.655       1
# 3        3     4  758.035  727.744  878.446   0.655       2
# 4        4     4  758.348  726.326  878.029   0.655       3
# ...    ...   ...      ...      ...      ...     ...     ...
# 3856  3856     3  780.095  745.130  896.535   0.403    3855
# 3857  3857     3  781.293  745.270  897.443   0.403    3856
# 3858  3858     3  782.406  745.245  898.459   0.403    3857
# 3859  3859     3  783.343  745.280  899.313   0.403    3858
# 3860  3860     3  782.619  746.180  898.340   0.403    3859
#
# [3861 rows x 7 columns]

# %%
rid = 864691135212946560
sid = 301225
sk = read_skeleton(skel_path+f'{rid}_{sid}', 
                                       f'{rid}_{sid}.swc')
f , ax = plt.subplots(figsize=(7,10))


skelplot.plot_tools.plot_verts(sk.vertices[:,[0,1]], sk.edges, radius = sk.vertex_properties['radius'],
                               skel_colors = sk.vertex_properties['compartment'], title=rid,  
                              invert_y=True, line_width = 5, plot_soma = True,
                             )

swc_path = f'{skel_path}{rid}_{sid}/{rid}_{sid}.swc'

df = read_swc(swc_path)

# %%
# test plot verts

rid = 864691135212946560
sid = 301225
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')
f , ax = plt.subplots(figsize=(7,10))


skelplot.plot_tools.plot_verts(sk.vertices, sk.edges, skel_colors = sk.vertex_properties['compartment'],
                               radius = sk.vertex_properties['radius'], title=rid, skel_alpha=.2,
                              invert_y=True, line_width = 3, plot_soma = True, )

swc_path = f'{skel_path}{rid}_{sid}/{rid}_{sid}.swc'
df = read_swc(swc_path)

# %%
# test plot_mw_skel

rid = 864691134884807418
sid = 518848
filename = f"{rid}_{sid}/{rid}_{sid}.h5"

mw = load_mw(skel_path, filename)
f , ax = plt.subplots(figsize=(7,10))

skelplot.plot_tools.plot_mw_skel(mw, pull_radius = True,
                              invert_y=True, line_width = 5, plot_soma = True,
                             pull_compartment_colors = True, plot_presyn = True,
                                plot_postsyn = True,)

# %%
rid = 864691134884807418
sid = 518848
filename = f"{rid}_{sid}/{rid}_{sid}.h5"

f , ax = plt.subplots(figsize=(7,10))

skelplot.plot_tools.plot_mw_skel(mw, pull_radius = False,
                              invert_y=True, line_width = 1, plot_soma = True,
                             pull_compartment_colors = False, plot_presyn = True,
                                plot_postsyn = True, presyn_alpha = .55, presyn_size = 24, 
                                postsyn_alpha = .1, )

# %%
rid = 864691134884807418
sid = 518848
filename = f"{rid}_{sid}/{rid}_{sid}.h5"

compartment_colors = {3: "orange", 4: "darkseagreen", 2: "magenta", 1: "hotpink"}

f , ax = plt.subplots(figsize=(7,10))

skelplot.plot_tools.plot_mw_skel(mw, pull_radius = False,
                              invert_y=True, line_width = 1, plot_soma = True,
                             pull_compartment_colors = True, plot_presyn = True,
                                plot_postsyn = True, presyn_alpha = .55, postsyn_size = 24, 
                                postsyn_alpha = .1, skel_color_map = compartment_colors)

# %%
# plot layers on this 
# I will load a layer aligned skeleton and plot average layer bounds on that 
sk = read_skeleton(layer_aligned_path, f'{sid}.swc')

f , ax = plt.subplots(figsize=(7,14))

skelplot.plot_tools.plot_skel(sk, line_width = 1, plot_soma = True,
                            skel_color_map = compartment_colors, 
                              pull_compartment_colors = True,
                               y_min_max=[10,-1_000],
                              invert_y = True
                                )
skelplot.plot_tools.plot_layer_lines(np.array(list(depths.values()))*[-1], ax = ax, labels = list(depths.keys()),
                                    line_styles = {"color": "gray", "linewidth": 1, "linestyle": "-"}, 
                                    buffer_space = -1.06)
ax.invert_xaxis()
ax.spines['right'].set_visible(False) 
#    ax.spines['left'].set_visible(False) 
ax.spines['top'].set_visible(False) 
#    ax.spines['bottom'].set_visible(False)

# %%
mw.seg_id
# Out:
# 864691134884807418

# %%
# plot layers that are different from each other 
f , ax = plt.subplots(figsize=(7,14))


line_styles = [{"color": "#d6ece8", "linewidth": 2, "linestyle": "-"},
               {"color": "#195046", "linewidth": .5, "linestyle": "-"},
               {"color": "#2c8484", "linewidth": 3, "linestyle": ":", 'alpha': .5},
              {"color": "#349c8c", "linewidth": 5, "linestyle": "--", 'alpha': .3},
              {"color": "#4cbcb4", "linewidth": 1, "linestyle": ":"},
              {"color": "#9bebc4", "linewidth": 3, "linestyle": "--"},
              {"color": "#2c6652", "linewidth": 1.5, "linestyle": "-"}]

sk = read_skeleton(layer_aligned_path, f'{sid}.swc')



skelplot.plot_tools.plot_skel(sk, line_width = 1, plot_soma = True,
                            skel_color_map = compartment_colors, 
                              pull_compartment_colors = True,
                               y_min_max=[10,-1_000],
                              invert_y = True
                                )
skelplot.plot_tools.plot_layer_lines(np.array(list(depths.values()))*[-1], ax = ax, labels = list(depths.keys()),
                                    line_styles = line_styles, 
                                    buffer_space = -1.06)
ax.invert_xaxis()

# %%
# just plot synapses



syn_res = [4,4,40]
presyn_verts = np.array([np.array(x) for x in (mw.anno['pre_syn']['pre_pt_position']).values])*syn_res
postsyn_verts = np.array([np.array(x) for x in (mw.anno['post_syn']['post_pt_position']).values])*syn_res

f , ax = plt.subplots(figsize=(7,10))
skelplot.plot_tools.plot_synapses(presyn_verts = presyn_verts, postsyn_verts = postsyn_verts, ax = ax,
                                 invert_y = True)

# %%
# plot three skeletons with subplots
rid = 864691134884807418
sid = 518848
sk = read_skeleton(skel_path+f'{rid}_{sid}', f'{rid}_{sid}.swc')

filename = f"{rid}_{sid}/{rid}_{sid}.h5"
mw = load_mw(skel_path, filename)

f , ax = plt.subplots(1,3,figsize=(30,30))

ax[0].set_xticks([])
ax[0].set_yticks([])
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[2].set_xticks([])
ax[2].set_yticks([])


skelplot.plot_tools.plot_verts(sk.vertices, sk.edges,  ax = ax[0], 
                              invert_y=True, line_width = 2.2, color = 'maroon', plot_soma = True)


skelplot.plot_tools.plot_skel(sk,  ax = ax[1], pull_radius = True, pull_compartment_colors = True,
                              invert_y=True, plot_soma = True, 
                             line_width = 3, color = 'darkslategray') 



skelplot.plot_tools.plot_mw_skel(mw, ax = ax[2], pull_radius = True,
                              invert_y=True, line_width = 5, plot_soma = True,
                             pull_compartment_colors = True, plot_presyn = True,
                                plot_postsyn = True)

# %%
from caveclient import CAVEclient
client = CAVEclient('minnie65_public_v343')
client.materialize.get_tables()
# Out:
# ['synapses_pni_2',
#  'nucleus_neuron_svm',
#  'nucleus_detection_v0',
#  'functional_coreg',
#  'allen_v1_column_types_slanted',
#  'aibs_column_nonneuronal',
#  'func_unit_em_match_release',
#  'proofreading_status_public_release',
#  'aibs_soma_nuc_metamodel_preds_v117']

# %%
proof_df = client.materialize.query_table('proofreading_status_public_release')
ax_proof_df = proof_df[~(proof_df['status_axon'] == 'non')]

# %%
ax_proof_df
# Out:
#       id valid    pt_supervoxel_id          pt_root_id            valid_id  \
# 21   602     t   90584228533843146  864691135182092034  864691135182092034
# 25   603     t   88543328459028709  864691135991773633  864691135991773633
# 232  604     t   88754572197488214  864691135509054217  864691135509054217
# 235  605     t   87980103627519388  864691135730543289  864691135730543289
# 283  412     t  106543777116022032  864691135884023664  864691135884023664
# ..   ...   ...                 ...                 ...                 ...
# 757  868     t   87966153708204874  864691136005148874  864691136005148874
# 758  869     t   89302953621658306  864691135571557157  864691135571557157
# 759  870     t   90518464128858597  864691136594839202  864691136594839202
# 760  871     t   91712464970366508  864691136175508486  864691136175508486
# 761  736     t  110706459687342783  864691136617461979  864691136617461979
#
#     status_dendrite status_axon              pt_position   cell_type
# 21         extended    extended  [187840, 207232, 22680]         NaN
# 25         extended    extended  [173008, 205856, 20391]         NaN
# 232        extended    extended  [174592, 206608, 20768]         NaN
# 235        extended    extended  [168992, 203840, 20211]  excitatory
# 283        extended    extended  [304080, 101984, 21853]         NaN
# ..              ...         ...                      ...         ...
# 757           clean       clean   [168912, 99616, 21487]  excitatory
# 758           clean       clean   [178624, 98128, 20611]  excitatory
# 759           clean       clean  [186928, 241744, 23718]         NaN
# 760           clean       clean  [195744, 224608, 23500]  excitatory
# 761        extended    extended  [333888, 183296, 23598]         NaN
#
# [410 rows x 9 columns]

# %%
from caveclient import CAVEclient
client = CAVEclient('minnie65_phase3_v1')
client.materialize.get_tables()
type_df = client.materialize.query_table('baylor_e_i_model_v1')

type_dict = type_df.set_index('pt_root_id')['cell_type'].to_dict()
type_dict
# Out:
#           id                          created  superceded_id valid  \
# 0          1 2021-11-10 17:55:35.652991+00:00            NaN     t
# 1          2 2021-11-10 17:55:35.654158+00:00            NaN     t
# 2          3 2021-11-10 17:55:35.655260+00:00            NaN     t
# 3          4 2021-11-10 17:55:35.656455+00:00            NaN     t
# 4          5 2021-11-10 17:55:35.657819+00:00            NaN     t
# ...      ...                              ...            ...   ...
# 81921  81922 2021-11-10 18:00:18.172578+00:00            NaN     t
# 81922  81923 2021-11-10 18:00:18.173709+00:00            NaN     t
# 81923  81924 2021-11-10 18:00:18.174814+00:00            NaN     t
# 81924  81925 2021-11-10 18:00:18.176211+00:00            NaN     t
# 81925  81926 2021-11-10 18:00:18.177324+00:00            NaN     t
#
#       classification_system   cell_type    pt_supervoxel_id  \
# 0       baylor_logistic_e_i  excitatory   76365205852192538
# 1       baylor_logistic_e_i  excitatory  108810146129558733
# 2       baylor_logistic_e_i  excitatory   96978301637215858
# 3       baylor_logistic_e_i  excitatory  120132366714027649
# 4       baylor_logistic_e_i  excitatory   76733130534637024
# ...                     ...         ...                 ...
# 81921   baylor_logistic_e_i  excitatory   96002140799376795
# 81922   baylor_logistic_e_i  excitatory   99858952577617332
# 81923   baylor_logistic_e_i  excitatory   89170874384910147
# 81924   baylor_logistic_e_i  excitatory   89660364023217237
# 81925   baylor_logistic_e_i  inhibitory   89745094869075291
#
#                pt_root_id              pt_position
# 0      864691135658329218   [84299, 173386, 16102]
# 1      864691135122981159  [320238, 210586, 26743]
# 2      864691135687329504  [234412, 136554, 27737]
# 3      864691134252908410  [402642, 157170, 23838]
# 4      864691135478541510   [87049, 293153, 20713]
# ...                   ...                      ...
# 81921  864691137197197121  [226898, 203667, 22852]
# 81922  864691135726446655  [255281, 103397, 21934]
# 81923  864691135279073441  [177311, 162605, 17715]
# 81924  864691135585983612  [181188, 139769, 24040]
# 81925  864691134918417162  [181650, 246671, 21529]
#
# [81926 rows x 9 columns]

# %%
type_dict = type_df.set_index('pt_root_id')['cell_type'].to_dict()
type_dict
# Out:
# {864691135658329218: 'excitatory',
#  864691135122981159: 'excitatory',
#  864691135687329504: 'excitatory',
#  864691134252908410: 'excitatory',
#  864691135478541510: 'excitatory',
#  864691135491674207: 'excitatory',
#  864691135719092273: 'excitatory',
#  864691136032916923: 'excitatory',
#  864691134428609977: 'inhibitory',
#  864691134441691943: 'excitatory',
#  864691135293935628: 'excitatory',
#  864691134940721507: 'excitatory',
#  0: 'excitatory',
#  864691136106404569: 'excitatory',
#  864691134577177340: 'excitatory',
#  864691135884956016: 'excitatory',
#  864691136741682012: 'excitatory',
#  864691134599202136: 'excitatory',
#  864691135909966505: 'excitatory',
#  864691134629357066: 'excitatory',
#  864691135874072206: 'excitatory',
#  864691134646607146: 'excitatory',
#  864691134648519538: 'excitatory',
#  864691134651920138: 'excitatory',
#  864691135754014925: 'excitatory',
#  864691134663715222: 'excitatory',
#  864691134668951908: 'excitatory',
#  864691135162753325: 'excitatory',
#  864691135273287441: 'excitatory',
#  864691135776128173: 'excitatory',
#  864691135082723063: 'excitatory',
#  864691134685607268: 'excitatory',
#  864691134685637988: 'excitatory',
#  864691135916196710: 'excitatory',
#  864691134703417700: 'excitatory',
#  864691136371215240: 'excitatory',
#  864691135429530672: 'excitatory',
#  864691135213606784: 'excitatory',
#  864691134735908218: 'excitatory',
#  864691134737851386: 'excitatory',
#  864691134742108478: 'excitatory',
#  864691135839991076: 'excitatory',
#  864691134743989494: 'excitatory',
#  864691135791187349: 'excitatory',
#  864691135408412617: 'inhibitory',
#  864691135113443225: 'excitatory',
#  864691134783471459: 'excitatory',
#  864691134783927395: 'excitatory',
#  864691134784325628: 'excitatory',
#  864691134786314346: 'excitatory',
#  864691135585649788: 'excitatory',
#  864691134792072188: 'excitatory',
#  864691134792514298: 'excitatory',
#  864691136109148856: 'excitatory',
#  864691134793187861: 'excitatory',
#  864691134800773453: 'excitatory',
#  864691134800869987: 'excitatory',
#  864691135754939486: 'excitatory',
#  864691135639442491: 'excitatory',
#  864691134435237532: 'excitatory',
#  864691134807855033: 'inhibitory',
#  864691134809096036: 'excitatory',
#  864691134812940327: 'inhibitory',
#  864691135462956350: 'excitatory',
#  864691136903407282: 'excitatory',
#  864691135848444766: 'excitatory',
#  864691134821365681: 'excitatory',
#  864691134940009827: 'excitatory',
#  864691136009414828: 'excitatory',
#  864691134940011107: 'excitatory',
#  864691134940011875: 'excitatory',
#  864691135447272788: 'excitatory',
#  864691134940012387: 'excitatory',
#  864691135696612250: 'excitatory',
#  864691136444752259: 'inhibitory',
#  864691135864385662: 'excitatory',
#  864691134940013155: 'excitatory',
#  864691135502754741: 'excitatory',
#  864691135889514377: 'excitatory',
#  864691135995181994: 'excitatory',
#  864691135323619996: 'excitatory',
#  864691135800026722: 'excitatory',
#  864691135539058290: 'excitatory',
#  864691135065837124: 'excitatory',
#  864691137197662785: 'excitatory',
#  864691135876651091: 'excitatory',
#  864691135590454283: 'excitatory',
#  864691135783103283: 'excitatory',
#  864691135841502691: 'excitatory',
#  864691134940025955: 'inhibitory',
#  864691134940050531: 'excitatory',
#  864691134940060771: 'excitatory',
#  864691135368080377: 'inhibitory',
#  864691135359534424: 'excitatory',
#  864691135988773120: 'excitatory',
#  864691135693677247: 'excitatory',
#  864691134940105315: 'inhibitory',
#  864691135940595110: 'excitatory',
#  864691136040039934: 'excitatory',
#  864691135952951843: 'inhibitory',
#  864691134940133219: 'inhibitory',
#  864691135618686607: 'excitatory',
#  864691135349251031: 'excitatory',
#  864691135135291673: 'excitatory',
#  864691134940152931: 'excitatory',
#  864691136144250420: 'excitatory',
#  864691136066210712: 'excitatory',
#  864691134918380554: 'excitatory',
#  864691135927423188: 'excitatory',
#  864691136194882892: 'excitatory',
#  864691136106510809: 'excitatory',
#  864691135889233289: 'excitatory',
#  864691134940166499: 'excitatory',
#  864691136091670196: 'excitatory',
#  864691135992055233: 'excitatory',
#  864691136379764181: 'excitatory',
#  864691134940414399: 'excitatory',
#  864691135754030285: 'excitatory',
#  864691134940737461: 'excitatory',
#  864691134942446594: 'excitatory',
#  864691134943480834: 'excitatory',
#  864691136419716503: 'inhibitory',
#  864691134943714306: 'excitatory',
#  864691134944548610: 'excitatory',
#  864691135208400249: 'excitatory',
#  864691134944772354: 'excitatory',
#  864691134945125634: 'excitatory',
#  864691134945178114: 'excitatory',
#  864691134945294082: 'inhibitory',
#  864691134945312770: 'excitatory',
#  864691135969638757: 'excitatory',
#  864691135359927896: 'excitatory',
#  864691134946331394: 'inhibitory',
#  864691135575360030: 'excitatory',
#  864691135937761589: 'excitatory',
#  864691135113885337: 'excitatory',
#  864691134947380988: 'excitatory',
#  864691135719140913: 'excitatory',
#  864691135274745573: 'excitatory',
#  864691134947381756: 'excitatory',
#  864691135394654197: 'excitatory',
#  864691135394654965: 'excitatory',
#  864691135884413808: 'excitatory',
#  864691135737469060: 'excitatory',
#  864691136371469448: 'excitatory',
#  864691134947383548: 'excitatory',
#  864691135213728056: 'excitatory',
#  864691135584477560: 'excitatory',
#  864691135572254501: 'excitatory',
#  864691134947385852: 'excitatory',
#  864691135582258541: 'excitatory',
#  864691136238115388: 'excitatory',
#  864691135594185259: 'excitatory',
#  864691135429247792: 'excitatory',
#  864691135762418230: 'excitatory',
#  864691135348996823: 'excitatory',
#  864691135655204546: 'excitatory',
#  864691134947390460: 'excitatory',
#  864691135304438953: 'excitatory',
#  864691135469349970: 'excitatory',
#  864691136904355506: 'excitatory',
#  864691136195151080: 'excitatory',
#  864691135571533037: 'excitatory',
#  864691135468242828: 'excitatory',
#  864691135726179135: 'excitatory',
#  864691134947393788: 'inhibitory',
#  864691135800182626: 'excitatory',
#  864691135772211019: 'excitatory',
#  864691134947394556: 'inhibitory',
#  864691135699927586: 'excitatory',
#  864691135066360132: 'excitatory',
#  864691134940932451: 'excitatory',
#  864691134947395836: 'excitatory',
#  864691135590960139: 'inhibitory',
#  864691135163326509: 'excitatory',
#  864691136297446683: 'excitatory',
#  864691134947397372: 'excitatory',
#  864691135946780196: 'excitatory',
#  864691134947398396: 'excitatory',
#  864691135940385702: 'excitatory',
#  864691136106216921: 'inhibitory',
#  864691134947399164: 'excitatory',
#  864691135575845150: 'excitatory',
#  864691134947400188: 'inhibitory',
#  864691135910377385: 'excitatory',
#  864691135404351214: 'excitatory',
#  864691136005906122: 'excitatory',
#  864691136011596707: 'excitatory',
#  864691136009492142: 'excitatory',
#  864691134947402236: 'excitatory',
#  864691135864663166: 'excitatory',
#  864691135569997958: 'excitatory',
#  864691136903812274: 'excitatory',
#  864691135841629667: 'excitatory',
#  864691135783080243: 'excitatory',
#  864691134947405564: 'excitatory',
#  864691135279269025: 'excitatory',
#  864691135889234313: 'excitatory',
#  864691135715769882: 'excitatory',
#  864691135954349320: 'inhibitory',
#  864691135233618521: 'excitatory',
#  864691135511477968: 'excitatory',
#  864691135687913184: 'excitatory',
#  864691135915774822: 'excitatory',
#  864691135754359501: 'excitatory',
#  864691134947407868: 'excitatory',
#  864691134947408124: 'excitatory',
#  864691135876651347: 'excitatory',
#  864691134947409404: 'inhibitory',
#  864691134947409660: 'excitatory',
#  864691136952581855: 'excitatory',
#  864691134947410172: 'excitatory',
#  864691134947410428: 'excitatory',
#  864691134947410684: 'excitatory',
#  864691135163520045: 'inhibitory',
#  864691135135815193: 'excitatory',
#  864691135502313026: 'excitatory',
#  864691135916089958: 'excitatory',
#  864691134947412988: 'excitatory',
#  864691135492001375: 'excitatory',
#  864691135407915977: 'excitatory',
#  864691136379695061: 'excitatory',
#  864691135341573041: 'excitatory',
#  864691135618435983: 'inhibitory',
#  864691135864999644: 'inhibitory',
#  864691134947415804: 'excitatory',
#  864691135495139472: 'inhibitory',
#  864691134947416572: 'excitatory',
#  864691135575542302: 'excitatory',
#  864691135516622803: 'excitatory',
#  864691135323951516: 'inhibitory',
#  864691136287041731: 'excitatory',
#  864691137197917761: 'excitatory',
#  864691135590681355: 'excitatory',
#  864691134947418364: 'inhibitory',
#  864691135867616278: 'excitatory',
#  864691135938472757: 'inhibitory',
#  864691134947419644: 'excitatory',
#  864691135292887478: 'excitatory',
#  864691134947420156: 'excitatory',
#  864691135386077269: 'excitatory',
#  864691135941845364: 'excitatory',
#  864691135518527626: 'excitatory',
#  864691136952581343: 'excitatory',
#  864691135577599237: 'excitatory',
#  864691135719142193: 'excitatory',
#  864691136031963579: 'excitatory',
#  864691134947459068: 'excitatory',
#  864691135576233246: 'excitatory',
#  864691134947459580: 'excitatory',
#  864691136135203979: 'excitatory',
#  864691136195151336: 'excitatory',
#  864691134947460860: 'excitatory',
#  864691136912424433: 'excitatory',
#  864691135475343168: 'excitatory',
#  864691135781531472: 'excitatory',
#  864691136266737396: 'inhibitory',
#  864691134947462396: 'excitatory',
#  864691136057073368: 'excitatory',
#  864691134947463164: 'excitatory',
#  864691136741185116: 'excitatory',
#  864691136990940821: 'inhibitory',
#  864691136106216665: 'excitatory',
#  864691135156274020: 'excitatory',
#  864691135776883885: 'excitatory',
#  864691135182802946: 'excitatory',
#  864691134947465212: 'inhibitory',
#  864691135889235337: 'excitatory',
#  864691136724314621: 'excitatory',
#  864691135361073735: 'excitatory',
#  864691135658768514: 'excitatory',
#  864691135741194091: 'excitatory',
#  864691136444216195: 'excitatory',
#  864691135576339230: 'excitatory',
#  864691135571800813: 'excitatory',
#  864691135851531719: 'excitatory',
#  864691134940733539: 'excitatory',
#  864691135856021806: 'excitatory',
#  864691135387602817: 'excitatory',
#  864691135841922275: 'excitatory',
#  864691135778084285: 'excitatory',
#  864691136106218201: 'excitatory',
#  864691136274483469: 'excitatory',
#  864691136419219863: 'excitatory',
#  864691136617862619: 'excitatory',
#  ...}

# %%
ax_proof_df['cell_type'] = ax_proof_df['pt_root_id'].map(type_dict)
ax_proof_df
# Out:
# <ipython-input-97-8656807644ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ax_proof_df['cell_type'] = ax_proof_df['pt_root_id'].map(type_dict)
#       id valid    pt_supervoxel_id          pt_root_id            valid_id  \
# 21   602     t   90584228533843146  864691135182092034  864691135182092034
# 25   603     t   88543328459028709  864691135991773633  864691135991773633
# 232  604     t   88754572197488214  864691135509054217  864691135509054217
# 235  605     t   87980103627519388  864691135730543289  864691135730543289
# 283  412     t  106543777116022032  864691135884023664  864691135884023664
# ..   ...   ...                 ...                 ...                 ...
# 757  868     t   87966153708204874  864691136005148874  864691136005148874
# 758  869     t   89302953621658306  864691135571557157  864691135571557157
# 759  870     t   90518464128858597  864691136594839202  864691136594839202
# 760  871     t   91712464970366508  864691136175508486  864691136175508486
# 761  736     t  110706459687342783  864691136617461979  864691136617461979
#
#     status_dendrite status_axon              pt_position   cell_type
# 21         extended    extended  [187840, 207232, 22680]         NaN
# 25         extended    extended  [173008, 205856, 20391]         NaN
# 232        extended    extended  [174592, 206608, 20768]         NaN
# 235        extended    extended  [168992, 203840, 20211]  excitatory
# 283        extended    extended  [304080, 101984, 21853]         NaN
# ..              ...         ...                      ...         ...
# 757           clean       clean   [168912, 99616, 21487]  excitatory
# 758           clean       clean   [178624, 98128, 20611]  excitatory
# 759           clean       clean  [186928, 241744, 23718]         NaN
# 760           clean       clean  [195744, 224608, 23500]  excitatory
# 761        extended    extended  [333888, 183296, 23598]         NaN
#
# [410 rows x 9 columns]

# %%
len(ax_proof_df[ax_proof_df['cell_type'] == 'inhibitory'])
# Out:
# 35
